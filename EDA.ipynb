# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_json = pd.read_json('myDatabase.items.json')

# %%
# dispaly all columns from json 
pd.set_option('display.max_columns', None)
df_json.head()
# Out:
#                       _id                                               name  \
# 0        1005005395269373  Pet Cat Accessories Anti-scratch Environmental...
# 1        1005005454781409  Laundry Cleaning Brush Dispenser Long Handle B...
# 2           4001350909662  Luxury Dinnerware Gold Cutlery Set 304 Stainle...
# 3  -p-1604875681220014080       Square Handicraft Decorative Nostalgic Resin
# 4        1005004064483695  Black Cat Nostalgia Poster Kraft Paper Prints ...
#
#   rating number_of_reviews number_of_orders    number_of_pecies  \
# 0                                   27 Sold                 657
# 1                                    4 Sold                  96
# 2                                    3 Sold  988 Sets available
# 3    NaN               NaN              NaN                 NaN
# 4    4.4                38         208 Sold  997 Bags available
#
#   number_of_likes country                                          image_url  \
# 0              35   China  https://ae01.alicdn.com/kf/S149333806ca846e193...
# 1               4   China  https://ae01.alicdn.com/kf/Se9342bb8bc63401d96...
# 2             121   China  https://ae01.alicdn.com/kf/H0376979dadc34a2d8d...
# 3             NaN   China  https://cc-west-usa.oss-accelerate.aliyuncs.co...
# 4             659   China  https://ae01.alicdn.com/kf/S265705cc1a644b4e97...
#
#        price        date          website  \
# 0       4.70  2023-05-10      Ali_express
# 1       2.35  2023-05-10      Ali_express
# 2       4.24  2023-05-10      Ali_express
# 3  0.53-0.85  2023-05-10  Cj_Dropshipping
# 4       1.81  2023-05-10      Ali_express
#
#                                               google   price_date_update  \
# 0  [{'URL': 'https://m.aliexpress.com/i/100500539...                 NaN
# 1  [{'URL': 'https://www.amazon.com/Multifunction...                 NaN
# 2  [{'URL': 'https://www.amazon.com/Silverware-Fl...                 NaN
# 3  [{'URL': 'https://www.etsy.com/market/square_r...   December 19, 2022
# 4  [{'URL': 'https://www.aliexpress.com/i/1005004...                 NaN
#
#   estimated_profit            Styles  \
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3             433%  [A set, A table]
# 4              NaN               NaN
#
#                            Estimated Processing Time          SPU  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3  1-3 days for 80% orders;\n4-8 days for 15% ord...  CJJT1643113
# 4                                                NaN          NaN
#
#   Product Attributes         Material Lists  \
# 0                NaN              NaN   NaN
# 1                NaN              NaN   NaN
# 2                NaN              NaN   NaN
# 3           Ordinary  Plastic, Others     0
# 4                NaN              NaN   NaN
#
#                                    price_differences  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[{'Name': 'A set', 'Price Difference': '0.85'...
# 4                                                NaN
#
#                                          description reviews Colors  \
# 0                                                NaN     NaN    NaN
# 1                                                NaN     NaN    NaN
# 2                                                NaN     NaN    NaN
# 3  {'Material': ' Plastic, Others', 'Package Size...      []    NaN
# 4                                                NaN     NaN    NaN
#
#   Electrical outlets      features details date_first_available Sizes  \
# 0                NaN  NaN      NaN     NaN                  NaN   NaN
# 1                NaN  NaN      NaN     NaN                  NaN   NaN
# 2                NaN  NaN      NaN     NaN                  NaN   NaN
# 3                NaN  NaN      NaN     NaN                  NaN   NaN
# 4                NaN  NaN      NaN     NaN                  NaN   NaN
#
#   best_sellers_rank Quantitys Defaults Models Painting sizes Capacitys  \
# 0               NaN       NaN      NaN    NaN            NaN       NaN
# 1               NaN       NaN      NaN    NaN            NaN       NaN
# 2               NaN       NaN      NaN    NaN            NaN       NaN
# 3               NaN       NaN      NaN    NaN            NaN       NaN
# 4               NaN       NaN      NaN    NaN            NaN       NaN
#
#   Specifications Specificationss Capacity sizes Formats Dimensionss  \
# 0            NaN             NaN            NaN     NaN         NaN
# 1            NaN             NaN            NaN     NaN         NaN
# 2            NaN             NaN            NaN     NaN         NaN
# 3            NaN             NaN            NaN     NaN         NaN
# 4            NaN             NaN            NaN     NaN         NaN
#
#   Power supplys Product Specificationss Carpet sizes Light Source Powers  \
# 0           NaN                     NaN          NaN                 NaN
# 1           NaN                     NaN          NaN                 NaN
# 2           NaN                     NaN          NaN                 NaN
# 3           NaN                     NaN          NaN                 NaN
# 4           NaN                     NaN          NaN                 NaN
#
#   Light Colors Interface Forms Product Specifications Types  \
# 0          NaN             NaN                    NaN   NaN
# 1          NaN             NaN                    NaN   NaN
# 2          NaN             NaN                    NaN   NaN
# 3          NaN             NaN                    NaN   NaN
# 4          NaN             NaN                    NaN   NaN
#
#   Fan Blade Diameters Applicable Models Pillowcase sizes Texts Please Inputs  \
# 0                 NaN               NaN              NaN   NaN           NaN
# 1                 NaN               NaN              NaN   NaN           NaN
# 2                 NaN               NaN              NaN   NaN           NaN
# 3                 NaN               NaN              NaN   NaN           NaN
# 4                 NaN               NaN              NaN   NaN           NaN
#
#   Color Classifications Specification Length Width Cms Suit Models   1s  \
# 0                   NaN                            NaN         NaN  NaN
# 1                   NaN                            NaN         NaN  NaN
# 2                   NaN                            NaN         NaN  NaN
# 3                   NaN                            NaN         NaN  NaN
# 4                   NaN                            NaN         NaN  NaN
#
#   Powers Heights Batterys Constellations Mould styles Power Supplys Puritys  \
# 0    NaN     NaN      NaN            NaN          NaN           NaN     NaN
# 1    NaN     NaN      NaN            NaN          NaN           NaN     NaN
# 2    NaN     NaN      NaN            NaN          NaN           NaN     NaN
# 3    NaN     NaN      NaN            NaN          NaN           NaN     NaN
# 4    NaN     NaN      NaN            NaN          NaN           NaN     NaN
#
#   Applicable Modelss 1PICs  颜色s Size Specificationss POD Color Total Price  \
# 0                NaN   NaN  NaN                  NaN       NaN         NaN
# 1                NaN   NaN  NaN                  NaN       NaN         NaN
# 2                NaN   NaN  NaN                  NaN       NaN         NaN
# 3                NaN   NaN  NaN                  NaN       NaN         NaN
# 4                NaN   NaN  NaN                  NaN       NaN         NaN
#
#   Lengths Mouse pad sizes Inchs  规格s Weights Item Numbers Bubble Types  \
# 0     NaN             NaN   NaN  NaN     NaN          NaN          NaN
# 1     NaN             NaN   NaN  NaN     NaN          NaN          NaN
# 2     NaN             NaN   NaN  NaN     NaN          NaN          NaN
# 3     NaN             NaN   NaN  NaN     NaN          NaN          NaN
# 4     NaN             NaN   NaN  NaN     NaN          NaN          NaN
#
#   Color Temperatures Appearance Colors  \
# 0                NaN               NaN
# 1                NaN               NaN
# 2                NaN               NaN
# 3                NaN               NaN
# 4                NaN               NaN
#
#   Specification (length * Width * Height)s 适用型号s Colloid Colors  \
# 0                                      NaN   NaN            NaN
# 1                                      NaN   NaN            NaN
# 2                                      NaN   NaN            NaN
# 3                                      NaN   NaN            NaN
# 4                                      NaN   NaN            NaN
#
#   Battery capacitys Pen Head Shapes Refill Colors Shapes Color Numbers  \
# 0               NaN             NaN           NaN    NaN           NaN
# 1               NaN             NaN           NaN    NaN           NaN
# 2               NaN             NaN           NaN    NaN           NaN
# 3               NaN             NaN           NaN    NaN           NaN
# 4               NaN             NaN           NaN    NaN           NaN
#
#   Colorss Pen Heads Pen Refill Colors Writtens number_of_pieces Cover Colors  \
# 0     NaN       NaN               NaN      NaN              NaN          NaN
# 1     NaN       NaN               NaN      NaN              NaN          NaN
# 2     NaN       NaN               NaN      NaN              NaN          NaN
# 3     NaN       NaN               NaN      NaN              NaN          NaN
# 4     NaN       NaN               NaN      NaN              NaN          NaN
#
#   Necklaces Dart Needle Counts 450mls Color classifications  \
# 0       NaN                NaN    NaN                   NaN
# 1       NaN                NaN    NaN                   NaN
# 2       NaN                NaN    NaN                   NaN
# 3       NaN                NaN    NaN                   NaN
# 4       NaN                NaN    NaN                   NaN
#
#   Specification Sizes Full Lengths Handle Materials Curtain sizes  \
# 0                 NaN          NaN              NaN           NaN
# 1                 NaN          NaN              NaN           NaN
# 2                 NaN          NaN              NaN           NaN
# 3                 NaN          NaN              NaN           NaN
# 4                 NaN          NaN              NaN           NaN
#
#   Net Contents Colours Patterns
# 0          NaN     NaN      NaN
# 1          NaN     NaN      NaN
# 2          NaN     NaN      NaN
# 3          NaN     NaN      NaN
# 4          NaN     NaN      NaN

# %%
print(df_json.columns)
# Out:
# Index(['_id', 'name', 'rating', 'number_of_reviews', 'number_of_orders',
#        'number_of_pecies', 'number_of_likes', 'country', 'image_url', 'price',
#        ...
#        'Dart Needle Counts', '450mls', 'Color classifications',
#        'Specification Sizes', 'Full Lengths', 'Handle Materials',
#        'Curtain sizes', 'Net Contents', 'Colours', 'Patterns'],
#       dtype='object', length=106)

# %%
# convert json to dataframe
df = pd.DataFrame(df_json)

# %%
# new datarame only with columns we need: _id and name 
df = df[['_id', 'name']]

# %%
df.head()
# Out:
#                       _id                                               name
# 0        1005005395269373  Pet Cat Accessories Anti-scratch Environmental...
# 1        1005005454781409  Laundry Cleaning Brush Dispenser Long Handle B...
# 2           4001350909662  Luxury Dinnerware Gold Cutlery Set 304 Stainle...
# 3  -p-1604875681220014080       Square Handicraft Decorative Nostalgic Resin
# 4        1005004064483695  Black Cat Nostalgia Poster Kraft Paper Prints ...

# %%
df.shape
# Out:
# (65177, 2)

# %%
# save dataframe to csv
df.to_csv('myDatabase.items.csv', index=False)

# %%
# check nulls 
df.isnull().sum()
# Out:
# _id     0
# name    0
# dtype: int64

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
ids = df['_id'].tolist()
names = df['name'].tolist()
